# %%
import pandas as pd
import numpy as np

# %%
df_co2= pd.read_csv(".\energyco2.csv")
df_co2
# Out:
#         Country                Energy_type  Year  Energy_consumption  \
# 0         World           all_energy_types  1980          292.899790
# 1         World                       coal  1980           78.656134
# 2         World                natural_gas  1980           53.865223
# 3         World  petroleum_n_other_liquids  1980          132.064019
# 4         World                    nuclear  1980            7.575700
# ...         ...                        ...   ...                 ...
# 55435  Zimbabwe                       coal  2019            0.045064
# 55436  Zimbabwe                natural_gas  2019            0.000000
# 55437  Zimbabwe  petroleum_n_other_liquids  2019            0.055498
# 55438  Zimbabwe                    nuclear  2019                 NaN
# 55439  Zimbabwe         renewables_n_other  2019            0.068089
#
#        Energy_production           GDP    Population  \
# 0             296.337228  27770.910281  4.298127e+06
# ...

# %% [markdown]
# Identificamos cuantos paises tiene este dataset, son 231 - 1 porque esta reguistrado como world

# %%
len(df_co2['Country'].unique())
# Out:
# 231

# %%
df_co2.isna().sum()
# Out:
# Country                            0
# Energy_type                        0
# Year                               0
# Energy_consumption             11153
# Energy_production              11151
# GDP                            15414
# Population                      9426
# Energy_intensity_per_capita     5082
# Energy_intensity_by_GDP         5082
# CO2_emission                    3826
# dtype: int64

# %%
df_irrad= pd.read_csv(".\Global horizontal irradiance 2010.csv")
df_irrad
# Out:
#                pais     enero   febrero     marzo      abril       mayo  \
# 0       Afghanistan  537602.0  635005.0  885965.0  1014586.0  1116551.0
# 1     Aland Islands   38074.0  133943.0  361771.0   590018.0   807283.0
# 2           Albania  260796.0  347113.0  619008.0   771422.0   918203.0
# 3           Algeria  652502.0  766332.0  954369.0  1044117.0  1132056.0
# 4    American Samoa  824779.0  807686.0  903215.0   797619.0   715583.0
# ..              ...       ...       ...       ...        ...        ...
# 235   Western Samoa       NaN       NaN       NaN        NaN        NaN
# 236           Yemen       NaN       NaN       NaN        NaN        NaN
# 237          Zambia       NaN       NaN       NaN        NaN        NaN
# 238        Zimbabwe       NaN       NaN       NaN        NaN        NaN
# 239        Mordovia  113272.0  233979.0  454923.0   732962.0   878229.0
#
#          junio      julio     agosto  septiembre   octubre  noviembre  \
# ...

# %%
#idnetificando valores nullos
df_irrad.isna().sum()
# Out:
# pais           0
# enero         32
# febrero       32
# marzo         32
# abril         32
# mayo          32
# junio         32
# julio         32
# agosto        32
# septiembre    32
# octubre       32
# noviembre     32
# diciembre     32
# dtype: int64

# %%
#eliminar valores nulos segun resultado anterior, eliminamos solo si todos los valores de la columna son NaN
df_irrad= df_irrad.dropna()
df_irrad
# Out:
#                                pais       enero   febrero     marzo  \
# 0                       Afghanistan  537602.000  635005.0  885965.0
# 1                     Aland Islands   38074.000  133943.0  361771.0
# 2                           Albania  260796.000  347113.0  619008.0
# 3                           Algeria  652502.000  766332.0  954369.0
# 4                    American Samoa  824779.000  807686.0  903215.0
# ..                              ...         ...       ...       ...
# 203                        Suriname  626276.000  646037.0  748922.0
# 204  Svalbard and Jan Mayen Islands       7.066    3646.0  122711.0
# 205                       Swaziland  751856.000  869610.0  723641.0
# 206                          Sweden   37735.000  125721.0  329022.0
# 239                        Mordovia  113272.000  233979.0  454923.0
#
#          abril       mayo      junio      julio     agosto  septiembre  \
# 0    1014586.0  1116551.0  1195268.0  1169426.0  1016882.0    945373.0
# ...

# %%
df_irrad.isna().sum()
# Out:
# pais          0
# enero         0
# febrero       0
# marzo         0
# abril         0
# mayo          0
# junio         0
# julio         0
# agosto        0
# septiembre    0
# octubre       0
# noviembre     0
# diciembre     0
# dtype: int64

# %%
df_irrad
# Out:
#                                pais       enero   febrero     marzo  \
# 0                       Afghanistan  537602.000  635005.0  885965.0
# 1                     Aland Islands   38074.000  133943.0  361771.0
# 2                           Albania  260796.000  347113.0  619008.0
# 3                           Algeria  652502.000  766332.0  954369.0
# 4                    American Samoa  824779.000  807686.0  903215.0
# ..                              ...         ...       ...       ...
# 203                        Suriname  626276.000  646037.0  748922.0
# 204  Svalbard and Jan Mayen Islands       7.066    3646.0  122711.0
# 205                       Swaziland  751856.000  869610.0  723641.0
# 206                          Sweden   37735.000  125721.0  329022.0
# 239                        Mordovia  113272.000  233979.0  454923.0
#
#          abril       mayo      junio      julio     agosto  septiembre  \
# 0    1014586.0  1116551.0  1195268.0  1169426.0  1016882.0    945373.0
# ...

# %%
df_irrad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 0 to 239
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pais        208 non-null    object
#  1   enero       208 non-null    float64
#  2   febrero     208 non-null    float64
#  3   marzo       208 non-null    float64
#  4   abril       208 non-null    float64
#  5   mayo        208 non-null    float64
#  6   junio       208 non-null    float64
#  7   julio       208 non-null    float64
#  8   agosto      208 non-null    float64
#  9   septiembre  208 non-null    float64
#  10  octubre     208 non-null    float64
#  11  noviembre   208 non-null    float64
#  12  diciembre   208 non-null    float64
# dtypes: float64(12), object(1)
# memory usage: 22.8+ KB

# %%
df_irrad['2010']= df_irrad.loc[:, 'enero':'diciembre'].mean(axis=1)
df_irrad
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\2827043829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irrad['2010']= df_irrad.loc[:, 'enero':'diciembre'].mean(axis=1)
#                                pais       enero   febrero     marzo  \
# 0                       Afghanistan  537602.000  635005.0  885965.0
# 1                     Aland Islands   38074.000  133943.0  361771.0
# 2                           Albania  260796.000  347113.0  619008.0
# 3                           Algeria  652502.000  766332.0  954369.0
# 4                    American Samoa  824779.000  807686.0  903215.0
# ..                              ...         ...       ...       ...
# 203                        Suriname  626276.000  646037.0  748922.0
# ...

# %%
df_irradicacion_1021=df_irrad[['pais', '2010']]

# %%
df_irradicacion_1021
# Out:
#                                pais           2010
# 0                       Afghanistan  867366.000000
# 1                     Aland Islands  431490.000000
# 2                           Albania  627617.166667
# 3                           Algeria  911867.083333
# 4                    American Samoa  817640.750000
# ..                              ...            ...
# 203                        Suriname  717759.833333
# 204  Svalbard and Jan Mayen Islands  311490.612167
# 205                       Swaziland  697455.500000
# 206                          Sweden  367427.000000
# 239                        Mordovia  503572.166667
#
# [208 rows x 2 columns]

# %%
def borrarnulos(urldataset):
    df_irrad= pd.read_csv(urldataset)
    df_irrad.isna().sum()
    df_irrad= df_irrad.dropna()
    return df_irrad

# %%
def irradianza_anual(df):
    promedio= df.loc[:, 'enero':'diciembre'].mean(axis=1)
    return promedio

# %%
a2011= borrarnulos(".\Global horizontal irradiance 2011.csv")
prom=irradianza_anual(a2011)
prom
# Out:
# 0      869917.000000
# 1      438228.333333
# 2      680690.833333
# 3      917218.500000
# 4      834630.416667
#            ...
# 203    743239.583333
# 204    298771.973083
# 205    728495.416667
# 206    370337.833333
# 239    455315.333333
# Length: 208, dtype: float64

# %%
df_irradicacion_1021['2011']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\2897812729.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2011']= prom
#                                pais           2010           2011
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2012= borrarnulos(".\Global horizontal irradiance 2012.csv")
prom=irradianza_anual(a2012)
df_irradicacion_1021['2012']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\978713206.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2012']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2013= borrarnulos(".\Global horizontal irradiance 2013.csv")
prom=irradianza_anual(a2013)
df_irradicacion_1021['2013']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\2531641459.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2013']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2014= borrarnulos(".\Global horizontal irradiance 2014.csv")
prom=irradianza_anual(a2014)
df_irradicacion_1021['2014']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\2747689723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2014']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2015= borrarnulos(".\Global horizontal irradiance 2015.csv")
prom=irradianza_anual(a2015)
df_irradicacion_1021['2015']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\1725522876.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2015']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2016= borrarnulos(".\Global horizontal irradiance 2016.csv")
prom=irradianza_anual(a2016)
df_irradicacion_1021['2016']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\2979158879.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2016']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2017= borrarnulos(".\Global horizontal irradiance 2017.csv")
prom=irradianza_anual(a2017)
df_irradicacion_1021['2017']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\1660400108.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2017']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2018= borrarnulos(".\Global horizontal irradiance 2018.csv")
prom=irradianza_anual(a2018)
df_irradicacion_1021['2018']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\470338658.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2018']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2019= borrarnulos(".\Global horizontal irradiance 2019.csv")
prom=irradianza_anual(a2019)
df_irradicacion_1021['2019']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\315921196.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2019']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2020= borrarnulos(".\Global horizontal irradiance 2020.csv")
prom=irradianza_anual(a2020)
df_irradicacion_1021['2020']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\3366147622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2020']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
a2021= borrarnulos(".\Global horizontal irradiance 2021.csv")
prom=irradianza_anual(a2021)
df_irradicacion_1021['2021']= prom
df_irradicacion_1021
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3920\1417404713.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irradicacion_1021['2021']= prom
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# ...

# %%
df_irradicacion_1021.to_csv(".\irradianza.csv", index=False)

# %%
dfi=pd.read_csv(".\irradianza.csv")
dfi
# Out:
#                                pais           2010           2011  \
# 0                       Afghanistan  867366.000000  869917.000000
# 1                     Aland Islands  431490.000000  438228.333333
# 2                           Albania  627617.166667  680690.833333
# 3                           Algeria  911867.083333  917218.500000
# 4                    American Samoa  817640.750000  834630.416667
# ..                              ...            ...            ...
# 203                        Suriname  717759.833333  743239.583333
# 204  Svalbard and Jan Mayen Islands  311490.612167  298771.973083
# 205                       Swaziland  697455.500000  728495.416667
# 206                          Sweden  367427.000000  370337.833333
# 207                        Mordovia  503572.166667  455315.333333
#
#               2012           2013           2014           2015  \
# 0    867146.833333  870355.750000  871399.416667  853522.333333
# ...

# %%
df_comsuopc=pd.read_csv('.\Consumo Energia Primaria Per Capita.csv')
df_comsuopc
# Out:
#                   Pais   1965   1966   1967   1968   1969   1970   1971  \
# 0               Canada  254.8  266.5  273.9  286.5  298.8  314.7  319.4
# 1               Mexico   23.9   24.6   24.3   25.6   27.3   28.2   28.8
# 2                   US  260.3  271.9  278.6  292.5  304.8  312.8  316.6
# 3            Argentina   53.4   54.3   55.0   56.1   57.1   53.3   55.6
# 4               Brazil   11.8   12.6   12.7   14.1   15.0   17.0   18.1
# ..                 ...    ...    ...    ...    ...    ...    ...    ...
# 87           Sri Lanka    3.4    3.4    3.4    3.5    3.5    5.7    5.7
# 88              Taiwan   19.6   20.4   21.5   24.0   24.5   26.0   31.9
# 89            Thailand    3.5    4.0    4.4    5.5    5.7    6.6    7.1
# 90             Vietnam    2.8    4.8    6.4    6.4    7.4    7.5    6.5
# 91  Other Asia Pacific   10.0   10.4   10.9   11.5   11.9   12.3   13.2
#
#      1972   1973  ...   2014   2015   2016   2017   2018   2019   2020   2021  \
# ...
